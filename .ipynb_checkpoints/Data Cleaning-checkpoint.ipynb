# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag
from sklearn.preprocessing import LabelEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import PolynomialFeatures
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn import set_config
set_config(display="diagram")
from sklearn.naive_bayes import ComplementNB
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve, roc_auc_score,plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import plot_roc_curve, auc,roc_curve,roc_auc_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('/Users/mahmoud/Car_Price_Prediction/complete_car_data.csv')

# %%
df
# Out:
#                                     Car Name      Mileage  \
# 0                  2016 Audi A4 2.0T Premium   92,124 mi.
# 1                 2015 Buick Enclave Leather  111,488 mi.
# 2            2012 Jeep Grand Cherokee Laredo  133,821 mi.
# 3                       2010 Toyota Camry LE  116,643 mi.
# 4                2016 Mazda Mazda6 i Touring  111,588 mi.
# ...                                      ...          ...
# 9802               2021 Mitsubishi Mirage ES   15,035 mi.
# 9803                   2006 Toyota Corolla S  154,352 mi.
# 9804               2008 Suzuki SX4 Base (A4)   46,460 mi.
# 9805  2014 Hyundai Santa Fe Sport 2.0L Turbo  152,296 mi.
# 9806                 2014 Honda Odyssey EX-L  124,233 mi.
#
#                       Dealer Name  Rating   Review Count    Price  \
# 0         NJ State Auto Used Cars     4.2  (672 reviews)  $14,359
# 1         NJ State Auto Used Cars     4.2  (672 reviews)  $13,517
# 2            Road Masters II Inc.     NaN   (77 reviews)   $9,995
# 3                    Arrow Motors     4.8  (220 reviews)   $9,999
# 4                    Arrow Motors     4.8  (220 reviews)  $13,499
# ...                           ...     ...            ...      ...
# 9802     CarVision of Maple Shade     NaN            NaN  $13,999
# 9803               Bethlehem Ford     NaN            NaN   $6,524
# 9804                   Napoli Kia     NaN            NaN   $8,924
# 9805  Pine Belt Chevy of Lakewood     NaN            NaN   $8,643
# 9806    Sloane Toyota of Glenside     NaN            NaN  $14,994
#
#                   Badge Label Car Rating  \
# 0                   Good Deal        4.2
# 1                   Fair Deal        4.2
# 2     Great Deal | $399 under        4.5
# 3                   Good Deal        5.0
# 4                   Good Deal        5.0
# ...                       ...        ...
# 9802                Fair Deal        4.9
# 9803  Great Deal | $194 under        5.0
# 9804  Great Deal | $508 under        4.9
# 9805                Good Deal        5.0
# 9806                Fair Deal        5.0
#
#                                             Car Reviews  \
# 0     ['April 22, 2021\nBy Tommy from San Antonio tx...
# 1     ['March 26, 2021\nBy Leo Appreciates a great r...
# 2     ['June 28, 2023\nBy CatTayl from Chatsworth, I...
# 3     ['January 24, 2023\nBy Pauline from St bernard...
# 4     ['October 30, 2022\nBy RChico456 from Las Vega...
# ...                                                 ...
# 9802  ['April 18, 2021\nBy LackeyMO from Neosho, Mis...
# 9803  ['April 27, 2023\nBy Kc from Whittier, MA\nUse...
# 9804  ['July  2, 2023\nBy Lee from Dayton ohio \nOwn...
# 9805  ['June 10, 2021\nBy Adelaide from NC\nOwns thi...
# 9806  ['December 20, 2022\nBy Mark Lotz from Shawnee...
#
#                          Accidents or damage  ...  \
# 0                              None reported  ...
# 1     At least 1 accident or damage reported  ...
# 2                              None reported  ...
# 3     At least 1 accident or damage reported  ...
# 4     At least 1 accident or damage reported  ...
# ...                                      ...  ...
# 9802  At least 1 accident or damage reported  ...
# 9803  At least 1 accident or damage reported  ...
# 9804                           None reported  ...
# 9805  At least 1 accident or damage reported  ...
# 9806  At least 1 accident or damage reported  ...
#
#                           Open recall                     Exterior color  \
# 0                       Not available             Glacier White Metallic
# 1     At least 1 open recall reported                   Iridium Metallic
# 2                       Not available  Brilliant Black Crystal Pearlcoat
# 3                       Not available                              Green
# 4                       Not available              Snowflake White Pearl
# ...                               ...                                ...
# 9802                    Not available                               Blue
# 9803                    Not available                 Silver Streak Mica
# 9804                    Not available                             Silver
# 9805                    Not available                       Mineral Gray
# 9806                    Not available              Modern Steel Metallic
#
#       Interior color         Drivetrain  \
# 0              Black    All-wheel Drive
# 1     Light Titanium  Front-wheel Drive
# 2              Black   Four-wheel Drive
# 3             Bisque  Front-wheel Drive
# 4              Black  Front-wheel Drive
# ...              ...                ...
# 9802           Black  Front-wheel Drive
# 9803   Dark Charcoal  Front-wheel Drive
# 9804               –    All-wheel Drive
# 9805            Gray  Front-wheel Drive
# 9806            Gray  Front-wheel Drive
#
#                                                     MPG      Fuel type  \
# 0     21–30\n\n\n\nBased on EPA mileage ratings. Use...  E85 Flex Fuel
# 1     17–24\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
# 2     16–23\n\n\n\nBased on EPA mileage ratings. Use...  E85 Flex Fuel
# 3     22–32\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
# 4     25–37\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
# ...                                                 ...            ...
# 9802  33–41\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
# 9803  30–38\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
# 9804  21–28\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
# 9805  19–27\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
# 9806  19–28\n\n\n\nBased on EPA mileage ratings. Use...       Gasoline
#
#            Transmission                                             Engine  \
# 0     8-Speed Automatic           2.0L I4 16V GDI DOHC Turbo Flexible Fuel
# 1     6-Speed Automatic                               3.6L V6 24V GDI DOHC
# 2             Automatic  3.6L V-6 DOHC, variable valve control, engine ...
# 3     6-Speed Automatic                              2.5L I4 16V MPFI DOHC
# 4        6-Speed Manual                               2.5L I4 16V GDI DOHC
# ...                 ...                                                ...
# 9802     5-Speed Manual                              1.2L I3 12V MPFI DOHC
# 9803  4-Speed Automatic                              1.8L I4 16V MPFI DOHC
# 9804  4-Speed Automatic                              2.0L I4 16V MPFI DOHC
# 9805  6-Speed Automatic                         2.0L I4 16V GDI DOHC Turbo
# 9806  6-Speed Automatic                              3.5L V6 24V MPFI SOHC
#
#                     VIN   Stock #
# 0     WAUBFAFLXGN009815     48142
# 1     5GAKRBKD6FJ125566     48175
# 2     1C4RJFAGXCC127988      4831
# 3     4T1BF3EK9AU561578  AU561578
# 4     JM1GJ1V52G1488572  G1488572
# ...                 ...       ...
# 9802  ML32AUHJ7MH010688    010688
# 9803  2T1BR32E16C696228   KBF2413
# 9804  JS2YB413385100353     F5618
# 9805  5XYZU3LA5EG187545  L187545T
# 9806  5FNRL5H63EB026489   1306351
#
# [9807 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9807 entries, 0 to 9806
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Car Name             9807 non-null   object
#  1   Mileage              9807 non-null   object
#  2   Dealer Name          9026 non-null   object
#  3   Rating               3900 non-null   float64
#  4   Review Count         6011 non-null   object
#  5   Price                9807 non-null   object
#  6   Badge Label          7796 non-null   object
#  7   Car Rating           9807 non-null   object
#  8   Car Reviews          9807 non-null   object
#  9   Accidents or damage  9807 non-null   object
#  10  1-owner vehicle      9807 non-null   object
#  11  Personal use only    9807 non-null   object
#  12  Open recall          9807 non-null   object
#  13  Exterior color       9807 non-null   object
#  14  Interior color       9807 non-null   object
#  15  Drivetrain           9807 non-null   object
#  16  MPG                  9021 non-null   object
#  17  Fuel type            9800 non-null   object
#  18  Transmission         9807 non-null   object
#  19  Engine               9807 non-null   object
#  20  VIN                  9807 non-null   object
#  21  Stock #              9026 non-null   object
# dtypes: float64(1), object(21)
# memory usage: 1.6+ MB
